# %% [markdown]
# 1. tell the machine , how many group to make .
# 2. drop random points according to no of group beong created
# 3. every point will choose the nearest group leader.
# 4. group leader will be moved towards the center .
# 5. repeat it until , everything got setteled.
