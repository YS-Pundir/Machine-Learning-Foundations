# %% [markdown]
# ## Encoding Categorical Data
# ### We will be doing two major things :
# 1. Label encoding
# 2. one-hot enconding
# * If there is just one type of text data then we don't apply encodding as machine learnign learn nothing from it .

# %% [markdown]
# ### Label encoding
# * As model can not work on the text data , it needed to be in numerical data .this is done with the help of encoding.
# 1. every cattegory to be changed in a unique number
#  for example : male=0,female =1
# 2. this tyoe of encoding to b eussed , where there mostly binary type of values .  for example : Gender , married or un-married

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
df=pd.read_csv("Cleaned_machine.csv")
df_label=df.copy()  # making a copy fo the data form csv file  

df_label=df_label.drop(columns=["UNITS","Magnitude","Subject","Group","Series_title_1"],axis=1)#  the drop returns a new copy of data 
print("Data After deleting the same values columns ")
print(df_label)
le=LabelEncoder()


df_label["STATUS_Labeled"]=le.fit_transform(df_label["STATUS"])
print("The labeled data is : ")
print(df_label)
# Out:
# Data After deleting the same values columns
#      Unnamed: 0 Series_reference   Period  Data_value STATUS  \
# 0             0      BDCQ.SEA1AA  2011.06       80078      F
# 1             1      BDCQ.SEA1AA  2011.09       78324      F
# 2             2      BDCQ.SEA1AA  2011.12       85850      F
# 3             3      BDCQ.SEA1AA  2012.03       90743      F
# 4             4      BDCQ.SEA1AA  2012.06       81780      F
# ..          ...              ...      ...         ...    ...
# 602         602      BDCQ.SEA1DS  2016.12       16245      R
# 603         603      BDCQ.SEA1DS  2017.03       17207      R
# 604         604      BDCQ.SEA1DS  2017.06       17243      R
# 605         605      BDCQ.SEA1DS  2017.09       17678      R
# 606         606      BDCQ.SEA1DS  2017.12       18145      R
#
#                                  Series_title_2       Series_title_3
# 0             Agriculture, Forestry and Fishing               Actual
# 1             Agriculture, Forestry and Fishing               Actual
# 2             Agriculture, Forestry and Fishing               Actual
# 3             Agriculture, Forestry and Fishing               Actual
# 4             Agriculture, Forestry and Fishing               Actual
# ..                                          ...                  ...
# 602  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 603  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 604  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 605  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 606  Electricity, Gas, Water and Waste Services  Seasonally adjusted
#
# [607 rows x 7 columns]
# The labeled data is :
#      Unnamed: 0 Series_reference   Period  Data_value STATUS  \
# 0             0      BDCQ.SEA1AA  2011.06       80078      F
# 1             1      BDCQ.SEA1AA  2011.09       78324      F
# 2             2      BDCQ.SEA1AA  2011.12       85850      F
# 3             3      BDCQ.SEA1AA  2012.03       90743      F
# 4             4      BDCQ.SEA1AA  2012.06       81780      F
# ..          ...              ...      ...         ...    ...
# 602         602      BDCQ.SEA1DS  2016.12       16245      R
# 603         603      BDCQ.SEA1DS  2017.03       17207      R
# 604         604      BDCQ.SEA1DS  2017.06       17243      R
# 605         605      BDCQ.SEA1DS  2017.09       17678      R
# 606         606      BDCQ.SEA1DS  2017.12       18145      R
#
#                                  Series_title_2       Series_title_3  \
# 0             Agriculture, Forestry and Fishing               Actual
# 1             Agriculture, Forestry and Fishing               Actual
# 2             Agriculture, Forestry and Fishing               Actual
# 3             Agriculture, Forestry and Fishing               Actual
# 4             Agriculture, Forestry and Fishing               Actual
# ..                                          ...                  ...
# 602  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 603  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 604  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 605  Electricity, Gas, Water and Waste Services  Seasonally adjusted
# 606  Electricity, Gas, Water and Waste Services  Seasonally adjusted
#
#      STATUS_Labeled
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 602               1
# 603               1
# 604               1
# 605               1
# 606               1
#
# [607 rows x 8 columns]

# %% [markdown]
# ### one-Hot encoding :
